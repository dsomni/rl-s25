# %% [markdown]
# # A2C Word test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import os
import sys
import warnings

import torch
import torch.optim as optim

ROOT_FOLDER = os.path.join(".", "..")
if ROOT_FOLDER not in sys.path:
    sys.path.insert(0, ROOT_FOLDER)


from a2c import A2CNet, evaluate, train_eval_loop
from dataset import RegexDataset
from environment_metrics import Environment, EnvSettings
from plot import plot_rewards
from rl import PolicyAgent as Agent
from rl import PolicyTrajectoryBuffer as TrajectoryBuffer
from utils import set_seed

warnings.filterwarnings("ignore")
logging.disable(logging.WARNING)
torch.backends.cudnn.deterministic = True
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Training

# %%
set_seed()
dataset = RegexDataset(*RegexDataset.from_disk("../../data/word.json"))
env = Environment(
    dataset,
    settings=EnvSettings(max_steps=5),
)

agent = Agent(temperature_coefficient=0)
buffer = TrajectoryBuffer(batch_size=64, device=DEVICE)

a2c_net = A2CNet(input_dim=env.state_space, output_dim=env.action_space).to(DEVICE)
a2c_optimizer = optim.Adam(a2c_net.parameters(), lr=1e-4)

# %%
episode_rewards = train_eval_loop(
    a2c_net,
    a2c_optimizer,
    agent,
    buffer,
    env,
    epochs=100,
    episodes=1000,
    device=DEVICE,
    eval_period=20,
    entropy_beta=0.01,
    clip_grad=10,
)
# Out:
# Epoch   1/100:	Reward: -195.8	Loss: 562.218
# Epoch   2/100:	Reward: -195.7	Loss: 561.532
# Epoch   3/100:	Reward: -196.4	Loss: 564.315
# Epoch   4/100:	Reward: -196.7	Loss: 565.132
# Epoch   5/100:	Reward: -196.0	Loss: 562.819
# Epoch   6/100:	Reward: -195.6	Loss: 561.350
# Epoch   7/100:	Reward: -195.8	Loss: 562.213
# Epoch   8/100:	Reward: -197.0	Loss: 566.404
# Epoch   9/100:	Reward: -196.3	Loss: 563.968
# Epoch  10/100:	Reward: -196.3	Loss: 563.830
# Epoch  11/100:	Reward: -196.2	Loss: 563.496
# Epoch  12/100:	Reward: -196.8	Loss: 565.712
# Epoch  13/100:	Reward: -196.5	Loss: 564.622
# Epoch  14/100:	Reward: -195.9	Loss: 562.529
# Epoch  15/100:	Reward: -195.2	Loss: 559.837
# Epoch  16/100:	Reward: -196.8	Loss: 565.844
# Epoch  17/100:	Reward: -196.2	Loss: 563.492
# Epoch  18/100:	Reward: -196.4	Loss: 564.346
# Epoch  19/100:	Reward: -195.2	Loss: 559.722
# Epoch  20/100:	Reward: -195.9	Loss: 562.310
# Epoch  21/100:	Reward: -196.9	Loss: 565.918
# Epoch  22/100:	Reward: -196.0	Loss: 562.874
# Epoch  23/100:	Reward: -196.4	Loss: 564.189
# Epoch  24/100:	Reward: -196.5	Loss: 564.537
# Epoch  25/100:	Reward: -196.5	Loss: 564.761
# Epoch  26/100:	Reward: -196.0	Loss: 562.733
# Epoch  27/100:	Reward: -195.9	Loss: 562.253
# Epoch  28/100:	Reward: -196.4	Loss: 564.170
# Epoch  29/100:	Reward: -195.8	Loss: 561.924
# Epoch  30/100:	Reward: -196.2	Loss: 563.391
# Epoch  31/100:	Reward: -196.4	Loss: 564.294
# Epoch  32/100:	Reward: -196.1	Loss: 563.091
# Epoch  33/100:	Reward: -195.0	Loss: 558.949
# Epoch  34/100:	Reward: -194.7	Loss: 557.923
# Epoch  35/100:	Reward: -193.7	Loss: 554.380
# Epoch  36/100:	Reward: -193.0	Loss: 551.452
# Epoch  37/100:	Reward: -191.2	Loss: 545.215
# Epoch  38/100:	Reward: -189.5	Loss: 538.894
# Epoch  39/100:	Reward: -185.9	Loss: 526.034
# Epoch  40/100:	Reward: -183.3	Loss: 516.402
# Epoch  41/100:	Reward: -150.7	Loss: 406.486
# Epoch  42/100:	Reward: -144.0	Loss: 384.155
# Epoch  43/100:	Reward: -143.5	Loss: 382.912
# Epoch  44/100:	Reward: -144.9	Loss: 387.271
# Epoch  45/100:	Reward: -146.3	Loss: 391.498
# Epoch  46/100:	Reward: -148.0	Loss: 397.053
# Epoch  47/100:	Reward: -145.8	Loss: 389.644
# Epoch  48/100:	Reward: -142.6	Loss: 379.835
# Epoch  49/100:	Reward: -136.4	Loss: 360.894
# Epoch  50/100:	Reward: -130.2	Loss: 342.250
# Epoch  51/100:	Reward: -124.0	Loss: 324.069
# Epoch  52/100:	Reward: -116.7	Loss: 303.161
# Epoch  53/100:	Reward: -109.3	Loss: 282.679
# Epoch  54/100:	Reward: -102.3	Loss: 264.587
# Epoch  55/100:	Reward: -95.5	Loss: 247.053
# Epoch  56/100:	Reward: -87.5	Loss: 227.474
# Epoch  57/100:	Reward: -79.3	Loss: 208.331
# Epoch  58/100:	Reward: -72.9	Loss: 193.544
# Epoch  59/100:	Reward: -64.6	Loss: 175.515
# Epoch  60/100:	Reward: -56.7	Loss: 159.382
# Epoch  61/100:	Reward: -49.2	Loss: 144.389
# Epoch  62/100:	Reward: -41.7	Loss: 130.525
# Epoch  63/100:	Reward: -34.1	Loss: 116.851
# Epoch  64/100:	Reward: -25.9	Loss: 103.149
# Epoch  65/100:	Reward: -19.8	Loss: 93.523
# Epoch  66/100:	Reward: -12.3	Loss: 82.456
# Epoch  67/100:	Reward: -3.8	Loss: 70.536
# Epoch  68/100:	Reward: 3.3	Loss: 61.528
# Epoch  69/100:	Reward: 9.2	Loss: 54.415
# Epoch  70/100:	Reward: 13.5	Loss: 49.359
# Epoch  71/100:	Reward: 19.9	Loss: 42.549
# Epoch  72/100:	Reward: 26.2	Loss: 36.327
# Epoch  73/100:	Reward: 34.2	Loss: 29.125
# Epoch  74/100:	Reward: 34.8	Loss: 28.587
# Epoch  75/100:	Reward: 39.1	Loss: 24.979
# Epoch  76/100:	Reward: 45.9	Loss: 19.990
# Epoch  77/100:	Reward: 51.0	Loss: 16.610
# Epoch  78/100:	Reward: 47.9	Loss: 18.695
# Epoch  79/100:	Reward: 54.7	Loss: 14.372
# Epoch  80/100:	Reward: 62.2	Loss: 10.511
# Epoch  81/100:	Reward: 69.5	Loss: 7.116
# Epoch  82/100:	Reward: 76.7	Loss: 4.488
# Epoch  83/100:	Reward: 83.0	Loss: 2.782
# Epoch  84/100:	Reward: 87.1	Loss: 1.815
# Epoch  85/100:	Reward: 90.9	Loss: 1.014
# Epoch  86/100:	Reward: 92.2	Loss: 0.878
# Epoch  87/100:	Reward: 93.6	Loss: 0.634
# Epoch  88/100:	Reward: 82.6	Loss: 2.950
# Epoch  89/100:	Reward: 80.1	Loss: 3.302
# Epoch  90/100:	Reward: 82.4	Loss: 2.702
# Epoch  91/100:	Reward: 86.1	Loss: 1.860
# Epoch  92/100:	Reward: 89.0	Loss: 1.297
# Epoch  93/100:	Reward: 92.4	Loss: 0.784
# Epoch  94/100:	Reward: 94.3	Loss: 0.489
# Epoch  95/100:	Reward: 95.4	Loss: 0.365
# Epoch  96/100:	Reward: 95.9	Loss: 0.322
# Epoch  97/100:	Reward: 95.8	Loss: 0.325
# Epoch  98/100:	Reward: 96.2	Loss: 0.274
# Epoch  99/100:	Reward: 95.8	Loss: 0.307
# Epoch 100/100:	Reward: 95.8	Loss: 0.289

# %%
plot_rewards(episode_rewards, title="A2C | [cat] Words", window=50)

# %% [markdown]
# ## Results

# %%
set_seed()
trained_regex, trained_reward = evaluate(a2c_net, env, agent, device=DEVICE)
print(f"Regex: {trained_regex}")
print(f"Total Reward: {trained_reward}")
# Out:
# Regex: [cat]+
# Total Reward: 49749.999963245005

# %%
set_seed()
random_regex, random_reward = evaluate(a2c_net, env, agent, random=True, device=DEVICE)
print(f"Regex: {random_regex}")
print(f"Total Reward: {random_reward}")
# Out:
# Regex: 7CbQr
# Total Reward: -65763.80009377065
