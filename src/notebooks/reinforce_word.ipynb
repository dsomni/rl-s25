# %% [markdown]
# # REINFORCE Word test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import os
import sys
import warnings

import torch
import torch.optim as optim

ROOT_FOLDER = os.path.join(".", "..")
if ROOT_FOLDER not in sys.path:
    sys.path.insert(0, ROOT_FOLDER)


from dataset import RegexDataset
from environment_metrics import Environment, EnvSettings
from plot import plot_rewards
from reinforce import PGN, evaluate, train_eval_loop
from rl import PolicyAgent as Agent
from rl import PolicyTrajectoryBuffer as TrajectoryBuffer
from utils import set_seed

warnings.filterwarnings("ignore")
logging.disable(logging.WARNING)
torch.backends.cudnn.deterministic = True
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Training

# %%
set_seed()
dataset = RegexDataset(*RegexDataset.from_disk("../../data/word.json"))
env = Environment(
    dataset,
    settings=EnvSettings(max_steps=5),
)

agent = Agent(temperature_coefficient=0)
buffer = TrajectoryBuffer(batch_size=64, device=DEVICE)

pgn = PGN(input_dim=env.state_space, output_dim=env.action_space).to(DEVICE)
pgn_optimizer = optim.Adam(pgn.parameters(), lr=1e-4)

# %%
episode_rewards = train_eval_loop(
    pgn,
    pgn_optimizer,
    agent,
    buffer,
    env,
    epochs=100,
    episodes=1000,
    device=DEVICE,
    eval_period=20,
    entropy_beta=0.01,
    clip_grad=10,
)
# Out:
# Epoch   1/100:	Reward: -196.0	Loss: -21.925
# Epoch   2/100:	Reward: -196.5	Loss: -20.923
# Epoch   3/100:	Reward: -196.4	Loss: -21.072
# Epoch   4/100:	Reward: -196.1	Loss: -21.701
# Epoch   5/100:	Reward: -195.8	Loss: -22.234
# Epoch   6/100:	Reward: -196.2	Loss: -21.539
# Epoch   7/100:	Reward: -196.5	Loss: -20.764
# Epoch   8/100:	Reward: -195.9	Loss: -22.057
# Epoch   9/100:	Reward: -195.7	Loss: -22.495
# Epoch  10/100:	Reward: -196.4	Loss: -21.085
# Epoch  11/100:	Reward: -195.7	Loss: -22.463
# Epoch  12/100:	Reward: -196.6	Loss: -20.546
# Epoch  13/100:	Reward: -196.1	Loss: -21.578
# Epoch  14/100:	Reward: -196.9	Loss: -20.077
# Epoch  15/100:	Reward: -195.9	Loss: -22.135
# Epoch  16/100:	Reward: -195.6	Loss: -22.619
# Epoch  17/100:	Reward: -196.6	Loss: -20.644
# Epoch  18/100:	Reward: -195.4	Loss: -23.087
# Epoch  19/100:	Reward: -196.2	Loss: -21.512
# Epoch  20/100:	Reward: -196.2	Loss: -21.571
# Epoch  21/100:	Reward: -194.9	Loss: -24.078
# Epoch  22/100:	Reward: -196.6	Loss: -20.613
# Epoch  23/100:	Reward: -196.3	Loss: -21.320
# Epoch  24/100:	Reward: -196.6	Loss: -20.660
# Epoch  25/100:	Reward: -196.2	Loss: -21.434
# Epoch  26/100:	Reward: -196.7	Loss: -20.402
# Epoch  27/100:	Reward: -195.7	Loss: -22.561
# Epoch  28/100:	Reward: -195.9	Loss: -22.086
# Epoch  29/100:	Reward: -195.4	Loss: -23.103
# Epoch  30/100:	Reward: -196.0	Loss: -21.781
# Epoch  31/100:	Reward: -195.6	Loss: -22.689
# Epoch  32/100:	Reward: -196.3	Loss: -21.361
# Epoch  33/100:	Reward: -194.9	Loss: -24.087
# Epoch  34/100:	Reward: -195.3	Loss: -23.265
# Epoch  35/100:	Reward: -193.0	Loss: -27.850
# Epoch  36/100:	Reward: -192.9	Loss: -28.060
# Epoch  37/100:	Reward: -191.2	Loss: -31.544
# Epoch  38/100:	Reward: -188.6	Loss: -36.665
# Epoch  39/100:	Reward: -186.7	Loss: -40.482
# Epoch  40/100:	Reward: -183.3	Loss: -47.195
# Epoch  41/100:	Reward: -179.0	Loss: -55.497
# Epoch  42/100:	Reward: -173.2	Loss: -66.364
# Epoch  43/100:	Reward: -138.0	Loss: -129.410
# Epoch  44/100:	Reward: -136.2	Loss: -132.371
# Epoch  45/100:	Reward: -135.0	Loss: -134.505
# Epoch  46/100:	Reward: -137.6	Loss: -130.291
# Epoch  47/100:	Reward: -137.5	Loss: -130.515
# Epoch  48/100:	Reward: -136.5	Loss: -132.069
# Epoch  49/100:	Reward: -133.8	Loss: -136.611
# Epoch  50/100:	Reward: -130.3	Loss: -142.263
# Epoch  51/100:	Reward: -124.1	Loss: -152.146
# Epoch  52/100:	Reward: -116.8	Loss: -163.377
# Epoch  53/100:	Reward: -109.3	Loss: -174.627
# Epoch  54/100:	Reward: -102.4	Loss: -184.872
# Epoch  55/100:	Reward: -83.2	Loss: -210.341
# Epoch  56/100:	Reward: -70.7	Loss: -226.065
# Epoch  57/100:	Reward: -65.6	Loss: -232.246
# Epoch  58/100:	Reward: -59.2	Loss: -239.290
# Epoch  59/100:	Reward: -46.0	Loss: -253.665
# Epoch  60/100:	Reward: -36.3	Loss: -263.214
# Epoch  61/100:	Reward: -33.9	Loss: -265.596
# Epoch  62/100:	Reward: -29.9	Loss: -269.265
# Epoch  63/100:	Reward: -28.2	Loss: -270.888
# Epoch  64/100:	Reward: -24.0	Loss: -274.662
# Epoch  65/100:	Reward: -17.6	Loss: -279.939
# Epoch  66/100:	Reward: -8.9	Loss: -286.936
# Epoch  67/100:	Reward: -2.6	Loss: -291.650
# Epoch  68/100:	Reward: 3.1	Loss: -295.659
# Epoch  69/100:	Reward: 9.7	Loss: -300.011
# Epoch  70/100:	Reward: 15.7	Loss: -303.743
# Epoch  71/100:	Reward: 18.8	Loss: -305.544
# Epoch  72/100:	Reward: 24.1	Loss: -308.467
# Epoch  73/100:	Reward: 31.8	Loss: -312.371
# Epoch  74/100:	Reward: 39.6	Loss: -315.917
# Epoch  75/100:	Reward: 44.7	Loss: -317.985
# Epoch  76/100:	Reward: 41.9	Loss: -316.914
# Epoch  77/100:	Reward: 48.6	Loss: -319.506
# Epoch  78/100:	Reward: 47.3	Loss: -319.018
# Epoch  79/100:	Reward: 50.0	Loss: -319.999
# Epoch  80/100:	Reward: 57.7	Loss: -322.518
# Epoch  81/100:	Reward: 66.2	Loss: -324.823
# Epoch  82/100:	Reward: 73.3	Loss: -326.335
# Epoch  83/100:	Reward: 80.8	Loss: -327.593
# Epoch  84/100:	Reward: 75.3	Loss: -326.613
# Epoch  85/100:	Reward: 75.0	Loss: -326.751
# Epoch  86/100:	Reward: 79.2	Loss: -327.435
# Epoch  87/100:	Reward: 83.5	Loss: -328.029
# Epoch  88/100:	Reward: 88.1	Loss: -328.564
# Epoch  89/100:	Reward: 91.1	Loss: -328.835
# Epoch  90/100:	Reward: 83.5	Loss: -327.942
# Epoch  91/100:	Reward: 79.7	Loss: -327.561
# Epoch  92/100:	Reward: 83.3	Loss: -328.086
# Epoch  93/100:	Reward: 85.9	Loss: -328.373
# Epoch  94/100:	Reward: 89.2	Loss: -328.735
# Epoch  95/100:	Reward: 92.2	Loss: -328.990
# Epoch  96/100:	Reward: 94.2	Loss: -329.127
# Epoch  97/100:	Reward: 95.6	Loss: -329.206
# Epoch  98/100:	Reward: 95.9	Loss: -329.235
# Epoch  99/100:	Reward: 96.2	Loss: -329.254
# Epoch 100/100:	Reward: 96.2	Loss: -329.253

# %%
plot_rewards(episode_rewards, title="REINFORCE | [cat] Words", window=50)

# %% [markdown]
# ## Results

# %%
set_seed()
trained_regex, trained_reward = evaluate(pgn, env, agent, device=DEVICE)
print(f"Regex: {trained_regex}")
print(f"Total Reward: {trained_reward}")
# Out:
# Regex: [tca]+
# Total Reward: 49749.999963245005

# %%
set_seed()
random_regex, random_reward = evaluate(pgn, env, agent, random=True, device=DEVICE)
print(f"Regex: {random_regex}")
print(f"Total Reward: {random_reward}")
# Out:
# Regex: WgWdV
# Total Reward: -65990.36637573005
