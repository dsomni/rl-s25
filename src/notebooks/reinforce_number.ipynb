# %% [markdown]
# # REINFORCE Number test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import os
import sys
import warnings

import torch
import torch.optim as optim

ROOT_FOLDER = os.path.join(".", "..")
if ROOT_FOLDER not in sys.path:
    sys.path.insert(0, ROOT_FOLDER)


from dataset import RegexDataset
from environment_metrics import Environment, EnvSettings
from plot import plot_rewards
from reinforce import PGN, evaluate, train_eval_loop
from rl import PolicyAgent as Agent
from rl import PolicyTrajectoryBuffer as TrajectoryBuffer
from utils import set_seed

warnings.filterwarnings("ignore")
logging.disable(logging.WARNING)
torch.backends.cudnn.deterministic = True
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Training

# %%
set_seed()
dataset = RegexDataset(*RegexDataset.from_disk("../../data/single_number.json"))
env = Environment(
    dataset,
    settings=EnvSettings(max_steps=5),
)

agent = Agent(temperature_coefficient=0)
buffer = TrajectoryBuffer(batch_size=64, device=DEVICE)

pgn = PGN(input_dim=env.state_space, output_dim=env.action_space).to(DEVICE)
pgn_optimizer = optim.Adam(pgn.parameters(), lr=1e-4)

# %%
episode_rewards = train_eval_loop(
    pgn,
    pgn_optimizer,
    agent,
    buffer,
    env,
    epochs=100,
    episodes=1000,
    device=DEVICE,
    eval_period=20,
    entropy_beta=0.01,
    clip_grad=10,
)
# Out:
# Epoch   1/100:	Reward: -193.2	Loss: -13.465
# Epoch   2/100:	Reward: -193.5	Loss: -13.137
# Epoch   3/100:	Reward: -193.4	Loss: -13.270
# Epoch   4/100:	Reward: -193.7	Loss: -12.829
# Epoch   5/100:	Reward: -192.9	Loss: -13.791
# Epoch   6/100:	Reward: -193.5	Loss: -13.126
# Epoch   7/100:	Reward: -193.7	Loss: -12.837
# Epoch   8/100:	Reward: -193.4	Loss: -13.177
# Epoch   9/100:	Reward: -193.6	Loss: -12.984
# Epoch  10/100:	Reward: -194.0	Loss: -12.443
# Epoch  11/100:	Reward: -193.3	Loss: -13.296
# Epoch  12/100:	Reward: -193.1	Loss: -13.573
# Epoch  13/100:	Reward: -193.2	Loss: -13.474
# Epoch  14/100:	Reward: -193.0	Loss: -13.708
# Epoch  15/100:	Reward: -193.1	Loss: -13.618
# Epoch  16/100:	Reward: -193.6	Loss: -12.947
# Epoch  17/100:	Reward: -193.0	Loss: -13.785
# Epoch  18/100:	Reward: -193.3	Loss: -13.362
# Epoch  19/100:	Reward: -193.5	Loss: -13.118
# Epoch  20/100:	Reward: -192.8	Loss: -14.016
# Epoch  21/100:	Reward: -193.0	Loss: -13.703
# Epoch  22/100:	Reward: -193.9	Loss: -12.528
# Epoch  23/100:	Reward: -192.1	Loss: -14.846
# Epoch  24/100:	Reward: -193.0	Loss: -13.685
# Epoch  25/100:	Reward: -194.4	Loss: -11.922
# Epoch  26/100:	Reward: -192.8	Loss: -14.054
# Epoch  27/100:	Reward: -193.5	Loss: -13.152
# Epoch  28/100:	Reward: -192.9	Loss: -13.843
# Epoch  29/100:	Reward: -193.6	Loss: -13.052
# Epoch  30/100:	Reward: -192.8	Loss: -13.897
# Epoch  31/100:	Reward: -194.1	Loss: -12.357
# Epoch  32/100:	Reward: -192.9	Loss: -13.814
# Epoch  33/100:	Reward: -193.1	Loss: -13.635
# Epoch  34/100:	Reward: -192.4	Loss: -14.523
# Epoch  35/100:	Reward: -191.3	Loss: -15.914
# Epoch  36/100:	Reward: -189.1	Loss: -18.587
# Epoch  37/100:	Reward: -188.2	Loss: -19.726
# Epoch  38/100:	Reward: -185.6	Loss: -23.022
# Epoch  39/100:	Reward: -182.0	Loss: -27.503
# Epoch  40/100:	Reward: -180.7	Loss: -29.073
# Epoch  41/100:	Reward: -176.7	Loss: -33.990
# Epoch  42/100:	Reward: -173.0	Loss: -38.450
# Epoch  43/100:	Reward: -168.3	Loss: -44.049
# Epoch  44/100:	Reward: -163.8	Loss: -49.404
# Epoch  45/100:	Reward: -158.7	Loss: -55.156
# Epoch  46/100:	Reward: -153.1	Loss: -61.491
# Epoch  47/100:	Reward: -146.8	Loss: -68.495
# Epoch  48/100:	Reward: -140.4	Loss: -75.478
# Epoch  49/100:	Reward: -135.4	Loss: -80.793
# Epoch  50/100:	Reward: -126.8	Loss: -89.672
# Epoch  51/100:	Reward: -121.7	Loss: -94.767
# Epoch  52/100:	Reward: -114.2	Loss: -101.917
# Epoch  53/100:	Reward: -107.1	Loss: -108.670
# Epoch  54/100:	Reward: -99.8	Loss: -115.183
# Epoch  55/100:	Reward: -93.2	Loss: -121.103
# Epoch  56/100:	Reward: -86.2	Loss: -126.904
# Epoch  57/100:	Reward: -78.5	Loss: -133.162
# Epoch  58/100:	Reward: -70.4	Loss: -139.498
# Epoch  59/100:	Reward: -63.5	Loss: -144.672
# Epoch  60/100:	Reward: -47.9	Loss: -155.292
# Epoch  61/100:	Reward: -38.6	Loss: -161.399
# Epoch  62/100:	Reward: -32.9	Loss: -164.808
# Epoch  63/100:	Reward: -29.8	Loss: -166.623
# Epoch  64/100:	Reward: -23.5	Loss: -170.234
# Epoch  65/100:	Reward: -16.7	Loss: -173.826
# Epoch  66/100:	Reward: -9.6	Loss: -177.389
# Epoch  67/100:	Reward: -2.1	Loss: -180.908
# Epoch  68/100:	Reward: 3.4	Loss: -183.355
# Epoch  69/100:	Reward: 10.3	Loss: -186.176
# Epoch  70/100:	Reward: 15.7	Loss: -188.329
# Epoch  71/100:	Reward: 23.7	Loss: -191.157
# Epoch  72/100:	Reward: 29.9	Loss: -193.205
# Epoch  73/100:	Reward: 38.0	Loss: -195.573
# Epoch  74/100:	Reward: 44.3	Loss: -197.241
# Epoch  75/100:	Reward: 42.9	Loss: -196.883
# Epoch  76/100:	Reward: 45.2	Loss: -197.483
# Epoch  77/100:	Reward: 50.9	Loss: -198.790
# Epoch  78/100:	Reward: 57.8	Loss: -200.175
# Epoch  79/100:	Reward: 64.2	Loss: -201.328
# Epoch  80/100:	Reward: 70.0	Loss: -202.203
# Epoch  81/100:	Reward: 77.0	Loss: -203.037
# Epoch  82/100:	Reward: 82.1	Loss: -203.542
# Epoch  83/100:	Reward: 85.4	Loss: -203.810
# Epoch  84/100:	Reward: 88.4	Loss: -204.042
# Epoch  85/100:	Reward: 84.4	Loss: -203.689
# Epoch  86/100:	Reward: 76.6	Loss: -203.035
# Epoch  87/100:	Reward: 78.5	Loss: -203.242
# Epoch  88/100:	Reward: 69.0	Loss: -202.120
# Epoch  89/100:	Reward: 72.8	Loss: -202.644
# Epoch  90/100:	Reward: 79.0	Loss: -203.334
# Epoch  91/100:	Reward: 84.9	Loss: -203.834
# Epoch  92/100:	Reward: 89.6	Loss: -204.158
# Epoch  93/100:	Reward: 92.7	Loss: -204.319
# Epoch  94/100:	Reward: 94.7	Loss: -204.411
# Epoch  95/100:	Reward: 95.5	Loss: -204.443
# Epoch  96/100:	Reward: 95.4	Loss: -204.444
# Epoch  97/100:	Reward: 95.7	Loss: -204.453
# Epoch  98/100:	Reward: 96.0	Loss: -204.468
# Epoch  99/100:	Reward: 96.2	Loss: -204.475
# Epoch 100/100:	Reward: 96.2	Loss: -204.472

# %%
plot_rewards(episode_rewards, title="REINFORCE | Single number", window=50)

# %% [markdown]
# ## Results

# %%
set_seed()
trained_regex, trained_reward = evaluate(pgn, env, agent, device=DEVICE)
print(f"Regex: {trained_regex}")
print(f"Total Reward: {trained_reward}")
# Out:
# Regex: \d+
# Total Reward: 49899.99994499999

# %%
set_seed()
random_regex, random_reward = evaluate(pgn, env, agent, random=True, device=DEVICE)
print(f"Regex: {random_regex}")
print(f"Total Reward: {random_reward}")
# Out:
# Regex: \^vlhI
# Total Reward: -65936.23015890368
