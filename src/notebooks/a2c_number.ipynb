# %% [markdown]
# # A2C Number test

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import os
import sys
import warnings

import torch
import torch.optim as optim

ROOT_FOLDER = os.path.join(".", "..")
if ROOT_FOLDER not in sys.path:
    sys.path.insert(0, ROOT_FOLDER)


from a2c import A2CNet, evaluate, train_eval_loop
from dataset import RegexDataset
from environment_metrics import Environment, EnvSettings
from plot import plot_rewards
from rl import PolicyAgent as Agent
from rl import PolicyTrajectoryBuffer as TrajectoryBuffer
from utils import set_seed

warnings.filterwarnings("ignore")
logging.disable(logging.WARNING)
torch.backends.cudnn.deterministic = True
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cpu')

# %% [markdown]
# ## Training

# %%
set_seed()
dataset = RegexDataset(*RegexDataset.from_disk("../../data/single_number.json"))
env = Environment(
    dataset,
    settings=EnvSettings(max_steps=5),
)

agent = Agent(temperature_coefficient=0)
buffer = TrajectoryBuffer(batch_size=64, device=DEVICE)

a2c_net = A2CNet(input_dim=env.state_space, output_dim=env.action_space).to(DEVICE)
a2c_optimizer = optim.Adam(a2c_net.parameters(), lr=1e-4)

# %%
episode_rewards = train_eval_loop(
    a2c_net,
    a2c_optimizer,
    agent,
    buffer,
    env,
    epochs=100,
    episodes=1000,
    device=DEVICE,
    eval_period=20,
    entropy_beta=0.01,
    clip_grad=10,
)
# Out:
# Epoch   1/100:	Reward: -192.9	Loss: 402.923
# Epoch   2/100:	Reward: -192.8	Loss: 402.431
# Epoch   3/100:	Reward: -193.5	Loss: 404.426
# Epoch   4/100:	Reward: -193.8	Loss: 405.011
# Epoch   5/100:	Reward: -193.1	Loss: 403.354
# Epoch   6/100:	Reward: -192.7	Loss: 402.301
# Epoch   7/100:	Reward: -192.9	Loss: 402.919
# Epoch   8/100:	Reward: -194.1	Loss: 405.923
# Epoch   9/100:	Reward: -193.4	Loss: 404.177
# Epoch  10/100:	Reward: -193.4	Loss: 404.078
# Epoch  11/100:	Reward: -193.3	Loss: 403.839
# Epoch  12/100:	Reward: -193.9	Loss: 405.427
# Epoch  13/100:	Reward: -193.6	Loss: 404.646
# Epoch  14/100:	Reward: -193.0	Loss: 403.146
# Epoch  15/100:	Reward: -192.3	Loss: 401.217
# Epoch  16/100:	Reward: -193.9	Loss: 405.522
# Epoch  17/100:	Reward: -193.3	Loss: 403.836
# Epoch  18/100:	Reward: -193.5	Loss: 404.448
# Epoch  19/100:	Reward: -192.3	Loss: 401.134
# Epoch  20/100:	Reward: -193.0	Loss: 402.989
# Epoch  21/100:	Reward: -194.0	Loss: 405.575
# Epoch  22/100:	Reward: -193.1	Loss: 403.410
# Epoch  23/100:	Reward: -193.4	Loss: 404.049
# Epoch  24/100:	Reward: -193.2	Loss: 403.489
# Epoch  25/100:	Reward: -192.7	Loss: 402.345
# Epoch  26/100:	Reward: -191.4	Loss: 398.874
# Epoch  27/100:	Reward: -190.3	Loss: 395.872
# Epoch  28/100:	Reward: -189.7	Loss: 394.151
# Epoch  29/100:	Reward: -187.6	Loss: 388.790
# Epoch  30/100:	Reward: -186.3	Loss: 385.329
# Epoch  31/100:	Reward: -184.3	Loss: 379.927
# Epoch  32/100:	Reward: -181.8	Loss: 373.690
# Epoch  33/100:	Reward: -177.8	Loss: 363.251
# Epoch  34/100:	Reward: -175.2	Loss: 356.396
# Epoch  35/100:	Reward: -172.1	Loss: 348.613
# Epoch  36/100:	Reward: -168.0	Loss: 338.228
# Epoch  37/100:	Reward: -164.7	Loss: 330.256
# Epoch  38/100:	Reward: -159.6	Loss: 317.588
# Epoch  39/100:	Reward: -154.0	Loss: 304.225
# Epoch  40/100:	Reward: -149.4	Loss: 293.121
# Epoch  41/100:	Reward: -120.2	Loss: 229.418
# Epoch  42/100:	Reward: -113.1	Loss: 214.359
# Epoch  43/100:	Reward: -111.2	Loss: 210.671
# Epoch  44/100:	Reward: -110.7	Loss: 209.812
# Epoch  45/100:	Reward: -110.3	Loss: 208.773
# Epoch  46/100:	Reward: -110.2	Loss: 208.771
# Epoch  47/100:	Reward: -106.8	Loss: 201.855
# Epoch  48/100:	Reward: -103.0	Loss: 194.586
# Epoch  49/100:	Reward: -96.8	Loss: 183.040
# Epoch  50/100:	Reward: -90.8	Loss: 172.150
# Epoch  51/100:	Reward: -85.0	Loss: 161.758
# Epoch  52/100:	Reward: -78.1	Loss: 150.039
# Epoch  53/100:	Reward: -71.3	Loss: 138.749
# Epoch  54/100:	Reward: -65.0	Loss: 129.005
# Epoch  55/100:	Reward: -58.9	Loss: 119.675
# Epoch  56/100:	Reward: -51.8	Loss: 109.358
# Epoch  57/100:	Reward: -44.6	Loss: 99.418
# Epoch  58/100:	Reward: -39.2	Loss: 91.903
# Epoch  59/100:	Reward: -31.9	Loss: 82.739
# Epoch  60/100:	Reward: -25.2	Loss: 74.681
# Epoch  61/100:	Reward: -18.9	Loss: 67.256
# Epoch  62/100:	Reward: -12.5	Loss: 60.523
# Epoch  63/100:	Reward: -6.2	Loss: 53.878
# Epoch  64/100:	Reward: 0.6	Loss: 47.242
# Epoch  65/100:	Reward: 5.5	Loss: 42.820
# Epoch  66/100:	Reward: 11.6	Loss: 37.608
# Epoch  67/100:	Reward: 18.7	Loss: 31.913
# Epoch  68/100:	Reward: 24.5	Loss: 27.779
# Epoch  69/100:	Reward: 27.6	Loss: 25.583
# Epoch  70/100:	Reward: 28.4	Loss: 24.965
# Epoch  71/100:	Reward: 33.9	Loss: 21.366
# Epoch  72/100:	Reward: 39.6	Loss: 18.012
# Epoch  73/100:	Reward: 47.0	Loss: 14.096
# Epoch  74/100:	Reward: 45.2	Loss: 14.970
# Epoch  75/100:	Reward: 48.2	Loss: 13.341
# Epoch  76/100:	Reward: 54.5	Loss: 10.506
# Epoch  77/100:	Reward: 58.8	Loss: 8.776
# Epoch  78/100:	Reward: 53.7	Loss: 10.860
# Epoch  79/100:	Reward: 60.1	Loss: 8.268
# Epoch  80/100:	Reward: 67.0	Loss: 5.969
# Epoch  81/100:	Reward: 73.8	Loss: 3.968
# Epoch  82/100:	Reward: 80.2	Loss: 2.467
# Epoch  83/100:	Reward: 85.7	Loss: 1.530
# Epoch  84/100:	Reward: 89.1	Loss: 1.010
# Epoch  85/100:	Reward: 92.4	Loss: 0.572
# Epoch  86/100:	Reward: 93.1	Loss: 0.526
# Epoch  87/100:	Reward: 94.2	Loss: 0.394
# Epoch  88/100:	Reward: 83.0	Loss: 2.064
# Epoch  89/100:	Reward: 80.3	Loss: 2.349
# Epoch  90/100:	Reward: 82.4	Loss: 1.933
# Epoch  91/100:	Reward: 86.2	Loss: 1.328
# Epoch  92/100:	Reward: 89.1	Loss: 0.921
# Epoch  93/100:	Reward: 92.5	Loss: 0.553
# Epoch  94/100:	Reward: 94.4	Loss: 0.343
# Epoch  95/100:	Reward: 95.5	Loss: 0.255
# Epoch  96/100:	Reward: 96.0	Loss: 0.226
# Epoch  97/100:	Reward: 95.9	Loss: 0.229
# Epoch  98/100:	Reward: 96.2	Loss: 0.194
# Epoch  99/100:	Reward: 95.9	Loss: 0.218
# Epoch 100/100:	Reward: 95.9	Loss: 0.207

# %%
plot_rewards(episode_rewards, title="A2C | Single number", window=50)

# %% [markdown]
# ## Results

# %%
set_seed()
trained_regex, trained_reward = evaluate(a2c_net, env, agent, device=DEVICE)
print(f"Regex: {trained_regex}")
print(f"Total Reward: {trained_reward}")
# Out:
# Regex: \d+
# Total Reward: 49899.99994499999

# %%
set_seed()
random_regex, random_reward = evaluate(a2c_net, env, agent, random=True, device=DEVICE)
print(f"Regex: {random_regex}")
print(f"Total Reward: {random_reward}")
# Out:
# Regex: v1\+.r
# Total Reward: -66791.97142874048
